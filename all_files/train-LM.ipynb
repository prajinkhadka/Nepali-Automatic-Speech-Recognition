# %%
import os
import torch
from sklearn.model_selection import train_test_split
from datasets import load_dataset, load_metric,Dataset,concatenate_datasets,set_caching_enabled, ClassLabel
import pandas as pd

import random
from IPython.display import display, HTML

import json
from transformers import Wav2Vec2CTCTokenizer,Wav2Vec2ForCTC,Wav2Vec2Processor,Trainer,TrainingArguments,Wav2Vec2FeatureExtractor

import re
set_caching_enabled(False)

import soundfile as sf
import torchaudio


import IPython.display as ipd

import numpy as np
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

from tqdm import tqdm
import torch

# Set environment variables
os.environ['WANDB_DISABLED '] = 'True'

import warnings
warnings.filterwarnings('ignore')

# %%
import logging
import transformers
transformers.logging.get_verbosity = lambda: logging.NOTSET

transformers.logging.get_verbosity()
# Out:
# 0

# %%
import datasets
datasets.logging.get_verbosity = lambda: logging.NOTSET

# %%
# tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %%
# feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)

# %%
from transformers import Wav2Vec2ProcessorWithLM
processor = Wav2Vec2ProcessorWithLM.from_pretrained("prajin/wav2vec2-large-xlsr-300m-nepali")

# %%
import glob 
data_dir  = "/workspace/data_processed/*"
data_dir_list = glob.glob(data_dir)
data_dir_list.remove('/workspace/data_processed/5')

# %%
data_dir_list
# Out:
# ['/workspace/data_processed/26',
#  '/workspace/data_processed/13',
#  '/workspace/data_processed/2',
#  '/workspace/data_processed/7',
#  '/workspace/data_processed/14',
#  '/workspace/data_processed/24',
#  '/workspace/data_processed/3',
#  '/workspace/data_processed/38',
#  '/workspace/data_processed/28',
#  '/workspace/data_processed/16',
#  '/workspace/data_processed/30',
#  '/workspace/data_processed/36',
#  '/workspace/data_processed/4',
#  '/workspace/data_processed/18',
#  '/workspace/data_processed/29',
#  '/workspace/data_processed/8',
#  '/workspace/data_processed/31',
#  '/workspace/data_processed/27',
#  '/workspace/data_processed/6',
#  '/workspace/data_processed/10',
#  '/workspace/data_processed/21',
#  '/workspace/data_processed/15',
#  '/workspace/data_processed/35',
#  '/workspace/data_processed/9',
#  '/workspace/data_processed/25',
#  '/workspace/data_processed/22',
#  '/workspace/data_processed/33',
#  '/workspace/data_processed/20',
#  '/workspace/data_processed/12',
#  '/workspace/data_processed/39',
#  '/workspace/data_processed/1',
#  '/workspace/data_processed/37',
#  '/workspace/data_processed/17',
#  '/workspace/data_processed/11',
#  '/workspace/data_processed/19',
#  '/workspace/data_processed/34',
#  '/workspace/data_processed/23',
#  '/workspace/data_processed/32']

# %%
data_set_list_total = []
for i in range(len(data_dir_list)):
    common_voice_val = Dataset.load_from_disk(data_dir_list[i])
    data_set_list_total.append(common_voice_val)

# %%
data_set_list_total = Dataset.load_from_disk('/workspace/data_processed/15')

# %%
len(data_set_list_total)
processor = Wav2Vec2Processor.from_pretrained("prajin/wav2vec2-large-xlsr-300m-nepali")

# %%
# data_set_list_total['labels']

# %%
label_str = processor.batch_decode(data_set_list_total['labels'], group_tokens=False)

# %%
label_str
# Out:
# ['तथा पूर्व सभासद् हुन्',
#  'योजना आयोगका उपाध्यक्षको',
#  'र एक अन्य फिल्मको',
#  'सन्दर्भमा कुरा गर्दा',
#  'संसारको पाँचौँ अग्लो हिमाल मनासलु यही क्षेत्रमा पर्छ',
#  'पङ्गेनी नेपाल भारत',
#  'त्यसभन्दा पनि अगाडि',
#  'कुनै समस्या',
#  'पढ्ने यन्त्र हो',
#  'माग गर्नेछ',
#  'भनेछन् काँचो नुन',
#  'नयाँ ताराहरू विभिन्न',
#  'संविधानसभामा जोडदार रूपमा',
#  'यसमध्ये लज्जा',
#  'यसमा खगोलीय उपग्रह',
#  'उनको साहुले',
#  'हालाकि सम्भान्त वर्ग',
#  'ठोरी तथा भारतीय',
#  'शनि र राहुको सामिप्य',
#  'सबै प्रयोगकर्ताको आपसी',
#  'उच्च माविको रूपमा',
#  'केराबारी गोर्खा जिल्लामा पर्छ',
#  'रूपमा उल्लेख गरियो',
#  'प्रधानद्वारा लेखिएको कृति हो',
#  'हात्तीलाई अङ्कुश लगाउँछ',
#  'भर्ना भए र',
#  'खेलाडीको एक पालो',
#  'उनी बाँच्ने समय',
#  'सम्पादक लियु भए',
#  'प्रसन्न भएमा चाँडै',
#  'आयो कुम्भै राना',
#  'अर्थात द्रङ्गको चारभागको',
#  'उत्तरपश्चिम सिमानामा पर्छ',
#  'क्षेत्रफल रहेको यस',
#  'बेलादेखि मकर मेला',
#  'वेल्समा बेलायती उपनिवेश',
#  'र अनेक कम्पनीका',
#  'उक्त अनलाइनलाई',
#  'पढाइ हुने गरेको छ',
#  'भन्ने माग राख्दै',
#  'दुईवटा निजी विद्यालय',
#  'मिति लेखिदिन्छ',
#  'खोला र लोहोरे खोलाको',
#  'भए राष्ट्र बैंक',
#  'सम्बन्धित जनतासँग',
#  'एउटा मन्त्र भन्छ',
#  'जस्तो कोलकाता दिल्ली',
#  'क्रियाहरू आरम्भ हुन्छन्',
#  'कतिपय त्यस्तै छन्',
#  'लिनक्स खुला श्रोत अन्तर्गतको युनिक्स अपरेटिङ सिस्टम हो',
#  'देशभरको प्याज क्षेत्रफलको',
#  'मध्य नेपालको चितवन',
#  'गर्न थाल्यो',
#  'भूतलीय यातायातको',
#  'देख्यो तथापि किनभने',
#  'वृक्षहरू पाइनु',
#  'संशोधन गरी',
#  'आविष्कार गरेर किराँतक्षेत्रमा',
#  'कोटो जस्तै धेरै',
#  'मन्दिर बनाउने निश् चय',
#  'चुनिएकी थिइन्',
#  'स्थानमा छन् पनि',
#  'शासित यो राज्य',
#  'शताब्दीयौं पुरानो',
#  'नौल्याई विषयवस्तुगत व्यापकता',
#  'धनुषा जिल्लाको जनकपुरमा',
#  'क्षमाको प्रभावबाट नै',
#  'जान्छ त्यो निषेधात्मक',
#  'भारतीय प्रसिद्ध लेखक',
#  'टेनिस तैराकी मैराथन',
#  'जब वर्तमान पात्रो',
#  'रिम पार्टीभित्रका केही',
#  'बचेका भए भोट',
#  'चर्चित भएपछि',
#  'तेईसौँ नक्षत्रका',
#  'दुर्लभ वनस्पति',
#  'ठुटो अथवा स्टब',
#  'धर्मेन् द्र हेमा मालिनी',
#  'अर्थात् दागडा स्वामित्व',
#  'करातेमा ब्ल्याक बेल्ट',
#  'पनि हिंसा हो',
#  'त्यसैले मलाई राम',
#  'पटक पटक रेडियोलाई',
#  'ठाकुरज्यू दह',
#  'यहाँ साधारणदेखि लियो',
#  'बढ्दा भए जुन',
#  'ग्यास पाइपलाइन निर्माण',
#  'लिच्छवीकालभन्दा अगाडिदेखि',
#  'यता कम्युनिष्ट पार्टीहरू',
#  'टाढाटाढाबाट मन्दिर',
#  'प्रथम महिलामध्येकी हुन्',
#  'गर्नु परेको थियो',
#  'सारियो जुन गाउँ',
#  'अध्ययन गर्नुभएको छ',
#  'हुनु र उनीहरूमा',
#  'उनी अहिले',
#  'सन्देश दिन्छ उफ्',
#  'हुँदै गएपछि पक्की',
#  'काठे पुल धेरै',
#  'देखाउन खोजिएको छ',
#  'खाम्लुङ भन्ने ठाउँमा',
#  'दर्ता भएको मितिले',
#  'थिए र पनि हजुरलाई',
#  'छोरालाई सिकाउन चाहेको',
#  'ब्ल्याकहेडेड गल भनिन्छ',
#  'संस्कृत ज त',
#  'अगाडि लामो समय',
#  'पुरानो वृक्ष हो',
#  'पछि आएर',
#  'जनगणना अनुसार डाडाकोतको',
#  'रहेर पुनरागमन गर्नुभएकोमा',
#  'कालदेखि अबसम्म',
#  'देवीघाटमा देहत्याग गरे',
#  'ह्याङ्क्स अहिलेका सबैभन्दा',
#  'जायज ठहरिन्छ',
#  'किराँत भाषाको हुनुको',
#  'अध्यक्षता गरेका थिए',
#  'उपयोगमा रहेको अनुमान',
#  'जीवनको सुरुवात गर्ने',
#  'भक्तजनहरूको पाइन्छ',
#  'गोकर्णको प्रमुख सांस्कृतिक',
#  'भूकम्पकी अधिष्ठात्री एउटी',
#  'धनुषा जिल्लाको जनकपुरमा',
#  'एक बायोग्राफरले उनलाई',
#  'उनीहरू शिक्षित भई',
#  'पाइने भए पनि',
#  'ज्ञान भयो',
#  'कृतिहरू मध्येको',
#  'वाइवाइ चाउचाउको दक्षिण',
#  'तपाईँंको नाम र',
#  'लडेका थिए',
#  'मुगलहरू तुर्क शासकहरूले',
#  'पिनेर पिठो बनाइन्छ',
#  'पुर्खाका सन्तान हुन्',
#  'दुष्यन्त भन्दछन्',
#  'पुरानो तालबाजा हो',
#  'धेरै गणतन्त्रहरूमा',
#  'विभिन्न प्रणालीहरूको',
#  'कमिक पुस्तक',
#  'हुँदा नियमित रूपमा',
#  'ग्रहहरूको वायुमण्डल अहिले',
#  'श्रीमान् ले यातना दिँदै',
#  'मोर्चाका महासचिव',
#  'केही सहयोग चाहिएमा',
#  'देशकै प्रथम अश्वेत',
#  'वर्षा ॠतुमा',
#  'यो टेम्प्लेटको स्थान',
#  'साटासाट गरौँ',
#  'भक्तपुर जितिसकेपछि पनि',
#  'नेपाली विकिपिडियामा राखिएका',
#  'आउटको सहारा लिनु',
#  'सर्च गरेर लिइएका छन्',
#  'समेत हुन्छ',
#  'बालबालिकाका लागि कक्षा',
#  'आइफोन फोर एस',
#  'हे राजा',
#  'कलावती पासवान मध्ये',
#  'रूपमा प्रयोग गर्दा',
#  'नाम यस प्रकार छ',
#  'खाली ठाउँमा निमको',
#  'पैदल हिँड्नुपर्छ',
#  'अञ्चलमा पर्ने काठमाडौँ',
#  'पोखरा उपत्यकाबाट बिजयपुर',
#  'अविलम्ब र नाटकीय थिए',
#  'सिकार खेल्न जान्थे',
#  'उनका जीवनमा थिए',
#  'छर्कको जनसङ्ख्या छ',
#  'केही समयमा नै',
#  'तपाईँले अपलोड गर्नुभएको',
#  'आन्दोलनको समयमा',
#  'हिंसाको निषेध हुनु',
#  'न्याय पाऊँ',
#  'उसलाई उठ्यो',
#  'खर्के डाँडा नौबिस',
#  'भुवाले ढाकिएको हुन्छ',
#  'दृष्टिले स्वतन्त्र हुन्छ',
#  'एकदम प्रभावित छ',
#  'दामोदर पाण्डे',
#  'नै गरिन्छ',
#  'एक अफ्रिकी माकुराको नाम',
#  'छिन्नमस्ता भगवती मनोकामना',
#  'मैले पढ्न पाइन',
#  'यो इस्लामको दोस्रो',
#  'धार्मिक स्थल हुन्',
#  'र प्रदूषित खानेकुरा',
#  'भन्दा बढी भयो',
#  'बलात्कार हुने',
#  'सानो भएका र',
#  'उनको पाठ गर्नाले',
#  'त्यस दिन बाँचेर',
#  'चलचित्रका हाँस्यकलाकार थिए',
#  'चनाखी परी राम्रो',
#  'जन्म पटनामा नै',
#  'जसको स्वाद',
#  'उनी रबर्ट पैट्रिकको',
#  'वृद्धि हुन्छ',
#  'जन्म भयो जसलाई',
#  'भएको छैन',
#  'गरिने मुख्य निर्देशनहरू',
#  'काश्मिरी मट्टा',
#  'योनी उन्नाइसमा वामन',
#  'अनौठो माछामध्येको',
#  'यस सङ्कटबाट पार',
#  'कुरो म चाँडै हेर्ने',
#  'प्रकाशित गरेको हो',
#  'इन्दिवर बडालज्यू हामी',
#  'यो भागमुनि मेरो',
#  'सक्छन् र धेरै',
#  'कन्नोजबाट आएको थिए',
#  'त्यस बेला मिश्रमा',
#  'नेपालमा बसेका बेला',
#  'नेपाल अधिराज्यकै सुन्दर',
#  'मुण्डको बध र अध्याय',
#  'तथा चम्बा राज्यमा',
#  'इलम सुरु भयो',
#  'खबर पाए अनि',
#  'थाम रहेका छन्',
#  'भाषा संस्कृति र परम्पराहरू',
#  'उहाँको विशेष रुचि छ',
#  'देवतालाई बिउ चढाई',
#  'भने यस संसारमा',
#  'जादु टुना र आपसी',
#  'कहिल्यै पनि थोप्लाहरूको',
#  'गद्दीको तयारी गर्दै थिए',
#  'क्षेत्र भएको',
#  'राख्ने र फुकुवा भई',
#  'क्वाँटी कच्चा आदि',
#  'बुद्धका शासनकालमा यस',
#  'पोखरीमा माटोको हात्ती',
#  'त्यस्तै आँप',
#  'अस्ट्रेलियाको नीतिलाई',
#  'त्यसपछि थोरै थोरै',
#  'कवीर जस्ता महासन्त',
#  'ठुलोधादिङमा पर्यटन व्यावसायको',
#  'लियोनल मेसीले पेनाल्टी',
#  'अन्तरङ्ग र बहिरङ्ग',
#  'जसको फलस्वरूप कुबाचा',
#  'उत्तर प्रदेशको एउटा',
#  'यसै गरी इटालियन',
#  'प्रयुक्त गरिन सक्छ',
#  'भएन बताएर सहयोग',
#  'लगायत अन्य गाविसहरूको',
#  'हुने र एक',
#  'कुनै पनि लेख',
#  'सम्बन्धित समाचार थोमस',
#  'बहुदलीय संसदीय व्यवस्था',
#  'दायर गरियो',
#  'भए पुरुष र महिलाहरूको',
#  'सामान्य जानकारी निम्नलिखित',
#  'देखा पर्छन् जब',
#  'अर्काले गलत भने',
#  'यो देश एक',
#  'समग्रमा इस्मा राज्य',
#  'दायाँ छेउमा भएको',
#  'पश्चिम र नर्वेको',
#  'यसबाहेक विद्युत प्राधिकरण',
#  'फ्रान्सको अधिनमा थियो',
#  'जिल्लामा एक',
#  'नेपालमै प्रशोधन भएको पहिलो नेपाली चलचित्र रक्षा यसका निर्माता निर्देशक प्रेम बानियाँ हुन्',
#  'नेपालको एक मात्र',
#  'प्रक्रिया छ जसका',
#  'एउटा ऐतिहासिक धार्मिक',
#  'दुई छोरी अमिता',
#  'क्षेत्रमा आफ्नो गुरू',
#  'आवश्यकता छ समाजमा',
#  'मन त लागिरा',
#  'प्रशासक हुनुहुन्छ',
#  'जसको नौ महिनापछि',
#  'इत्यादि खामको धेरै',
#  'भ्रष्टाचारबाट पीडित अरूको',
#  'गाविसका सीमा जोडिएका',
#  'सरोजजी पछिल्लो समयमा',
#  'अर्को नयाँ टेम्प्लेट',
#  'अभिनयको सुरुवात गरिन्',
#  'कुरो बुझ्नु पर्छ',
#  'भारतीलाई पनि',
#  'विभेद छ',
#  'यो उपाधिबाट लेखनाथको',
#  'अन्तर्राष्ट्रिय समुदाय',
#  'हजुर विजयी हुनु हुनेछ',
#  'आमा किरण यादवको',
#  'यसको बाहेक कहिलेकाहिँ',
#  'सैनिक तालिम',
#  'स्वास्थ्य सम्बन्धि चालचलनलाई',
#  'केही कलाकारको मृगौलामा',
#  'यसबाहेक उसले काबुलमा',
#  'विरोध सम्म प्रारम्भिक',
#  'तयार गरिन्छ',
#  'यिनी टङ्कप्रसाद आचार्यको',
#  'परिणत गर्दै हामी',
#  'विख्यात कला',
#  'उचित छ कि',
#  'कैरा भारतका सहरहरू',
#  'वर्षाका महिनाहरू बाहेक',
#  'समयमा एकै शाखा',
#  'तलका लेखहरू हेर्नुहोला',
#  'धरतीका मनुष्यहरूलाई मार्गदर्शनको',
#  'पढेका थिए',
#  'इतिहास प्रकाशित',
#  'निरन्तर विकास गरे',
#  'जन्मोत्सव भवानीजी नेपालको',
#  'कुनै गल्ती देखियो',
#  'शिक्षा लिनुभएकी कपाली',
#  'परिवारलाई प्राथमिकता',
#  'ईटानगर हिमालयको',
#  'अप्टिक्सको अध्ययन गरे',
#  'गर्टिनले ऐतिहासिक',
#  'विशिष्ट धार्मिक पर्व',
#  'महिनौँदेखि खोजिरहेको थिएँ',
#  'अन्य भाषा बोल्नेको',
#  'विकि पेज बनाउन',
#  'तर आजभोलि यस्ता',
#  'त्यसकै साथमा रहेको',
#  'ग्रसित हुन्छ',
#  'स्थित देश हो',
#  'रूपमा देखिइन्',
#  'उनका बुवा जिम्मी',
#  'मानव अधिकारको लागि',
#  'घेरेर चौतारीको',
#  'वा साक्षर भएपछि',
#  'गरेका वैँसहरूको बारेमा',
#  'उमेर सानै भए',
#  'तयारी गर्न नपाउँदै',
#  'धेरै महत्त्वपूर्ण ऐतिहासिक',
#  'दुई किलो ग्राम',
#  'त्यसैगरी स्वामित्व बोधक',
#  'कलेज हो',
#  'सूर्यको प्रभाको',
#  'निमन्त्रणा गरिन्छ',
#  'लागि उपयोग गरे',
#  'यो एक पेय',
#  'कार्य जीवनदास',
#  'कार्य नरहरि',
#  'उनी दरभङ्गा बिहार',
#  'राजालाई लिइन्छ',
#  'सुरुवात गरे पनि',
#  'कि मैले आरम्भ',
#  'अब एकता देखाउने',
#  'हरियो वनले घेरिएको छ',
#  'अधिकांश अस्ट्रेलियाली',
#  'साधकहरूको लागि महत्त्वपूर्ण',
#  'मिटरसम्मको उचाइमा',
#  'हुँदा प्युठानको फलाम',
#  'पुरा म गर्छु मनले',
#  'भाषालाई पछिल्लो वैदिक',
#  'अप्सरा किन्नर तथा',
#  'पनि यसै क्षेत्रमा पर्दछ',
#  'काम थाले',
#  'शिक्षा पाएका गोपाल',
#  'लक्ष्य हो',
#  'वृत्ताकार चकटि हुन्छ',
#  'अङ्ग्रेजी बैंकहरूका एक',
#  'थिए र कथित',
#  'जब हामीले थाहा पायौं',
#  'चितवन जिल्ला',
#  'त्यसैले पहिला गरेको',
#  'रचना हुन्छ',
#  'उनले भायोलिन',
#  'जाली भने टालिँदैन',
#  'शर्माकै कारण राहुलले',
#  'भारतमा पर्दछन्',
#  'जगत् जननी',
#  'उनले आफ्नो छोरा',
#  'निर्णय लिए',
#  'महोत्तरी निवासी',
#  'निकाल्छ र मानिसका',
#  'कुनै आइपिले खराब',
#  'प्रत्यक्ष शासन',
#  'सार्वजनिक भएको छ',
#  'कार्तिक महिनामा नृसिंह',
#  'मानसिक सन्तुलन काठमाडौँ',
#  'नामक ग्रन्थमा उल्लेख',
#  'गर्न अनुरोध छ',
#  'झुपडीमा बस्न लगाइन्छ',
#  'परमाणु बमको अनियन्त्रित',
#  'जिरालाई पानीमा पिनेर',
#  'काम भएको थियो',
#  'यो क्षेत्र',
#  'काठमाडौँ उपत्यका',
#  'बन्द हुन्छ निबन्ध',
#  'स्कटल्याण्डबाट भागेर इङ्गल्याण्ड',
#  'कहाँ भेटिन्छे',
#  'कमाइले खान पुग्छ',
#  'दिनु हुँदैन',
#  'चिन कोरिया तथा',
#  'सासनी वंश इस्लामको',
#  'उनीहरूका अनुसार यसको',
#  'र फेरि त्यही',
#  'कोली शब्द जातिविशेष',
#  'जनाउन सक्छ',
#  'प्याज काँचै खाँदा',
#  'आवश्यकता बढ्दै गएको',
#  'स्तरमा वृद्धि गरेर',
#  'प्रजातान्त्रिक जनमुक्ति पार्टी नेपालको एउटा राजनीतिक दल हो',
#  'राज्य सिक्किमको',
#  'गुरुत्वार्षणका विरुद्ध एउटा',
#  'ऐतिहासिक नगर हो',
#  'सल्लाहको लागि',
#  'सिर्जना गर्नुभयो',
#  'बढाएका थिए',
#  'पाए साथ मिठो',
#  'भएबाट यो जाति',
#  'नङ मानिस लगायतका',
#  'आठ रेसादार प्रजातिका',
#  'यसलाई अङ्ग्रेजीमा कमन',
#  'टर्मिनेटर सेल्वेसनको बजेट',
#  'अबुल फजल इब्न',
#  'शरीरमा जति प्रहार',
#  'काँडे भ्याकुर समुद्र',
#  'फेन्टासी टेलिभिजन शृङ्खला',
#  'केशवराज पैाडेल',
#  'गोपाल पाण्डे',
#  'सदा नतमस्तक रहनेछ',
#  'आयुर्वेद ग्रन्थ',
#  'उत्तरमा रतनचुरा भद्रकाली',
#  'नेकपा एमाले',
#  'पप संस्कृति लोकप्रिय',
#  'सास फेर्न गाह्रो देखिने',
#  'केही गीतहरू कव्वालीको',
#  'परिवारको इच्छा विपरीत',
#  'गते शुक्रबारदेखि प्रत्येक',
#  'कालीप्रसाद रिजालद्वारा लेखिएको',
#  'अस्वीकार गरिदिए कि',
#  'पुस्तकका पात्रहरूजस्तै उनी पनि स्वतन्त्र भएर बाँच्न चाहन्थिइन्',
#  'आवाजमा परिवर्तन गराएर',
#  'अनिवार्य रूपमा',
#  'लिएको अनुमान गरिन्छ',
#  'चक्रवर्तीसँगको भेटले उहाँको',
#  'जुन मरिचको इटालियन',
#  'पिएफको इतिहास',
#  'नयाँ सरकारले संविधान',
#  'गेल क्यारिगरद्वारा',
#  'युकेशजी आज धेरै',
#  'भने हामी त्यहाँ',
#  'उक्त निर्णय त्रुटिपूर्ण',
#  'उसको उदार सहिष्णु',
#  'महानवमीका दिन',
#  'साथमा सुन्दर हुन्छन्',
#  'स्रोतका अनुसार',
#  'संगम स्थल थियो',
#  'पञ्चायतको अर्थात् हालको',
#  'पछि राजाले खोजतलास गर्दा अनैतिक नभएको पत्ता लाग्यो',
#  'जाति आदिको नाममा',
#  'अवकाश ग्रहण गर्दै',
#  'यो कुरा मैले',
#  'यूजेनिक्सको अनेक समस्याहरूमा',
#  'रगत आउने',
#  'मार्न पनि सक्छन्',
#  'च्याउलाई भातमा मिसाउँदा',
#  'अझ कहिलेकाहिँ अरू केही हिमाली भाषासँग यसको विभेद छुट्याउनै कठिन हुन्छ',
#  'साँझमा आआफ्नो घरको',
#  'मात्रको लागि',
#  'क्षेत्रहरूमा यो अपेक्षाकृत',
#  'मेरो विचारमा सायद',
#  'घाउ चाहे सानो',
#  'कारणले हुन्छ',
#  'पदवियोग भनिन्छ',
#  'बोट्समा पृष्ठ बनाउनुहोला',
#  'प्यारामेडिकल क्षेत्रका',
#  'राजनीतिक मनमुटावले गर्दा',
#  'तर त्यस चलचित्रपछि',
#  'अरविन्द ठाकुर',
#  'आफ्नो घरवरपर',
#  'जीवनको सुरुवात गर्ने',
#  'मुख्य आहारा बनेको',
#  'व्यक्तिले आफ्नो सम्पत्ति',
#  'असान्दर्भिक र नराम्रो',
#  'सम्मेलनले प्रचण्डपथको अवधारणा',
#  'दुर्योधन कर्णलाई आफ्नो',
#  'डा एच एस',
#  'छोराछोरी नातिनातिना समेत',
#  'ढुङ्गा र तरबारको धारलाई छोएर कसम खाई सो नाचको सुरुवात गर्ने चलन छ',
#  'पहिला कुमाउँ अधिराज्य',
#  'गल्ती बाहेक',
#  'प्रखर स्वभावका यिनलाई',
#  'अप्टिकल शब्दबाट नै',
#  'हो कैलपछि ऊ',
#  'औद्योगिक विकास हासिल',
#  'हेर्दा यो जिल्ला',
#  'अङ्ग्रेजी बैंकहरूका एक',
#  'यो समयमा पोथीहरूलाई',
#  'लेहलका गाउँवासीहरूले',
#  'सुरु भइसकेको थियो',
#  'तर्फ एकका माथि',
#  'इन्द्रेणीसमेत लाग्छ यहाँ',
#  'लागि सबै उपकरण',
#  'अन्तर्गत गरिन्छ',
#  'कारण उनी चाँडै',
#  'त्रैमासिक अवधिमा हुन्छ',
#  'पूजा गरेपछि फुस्रो',
#  'दरबार रहेको लिगलिगकोट',
#  'च्याब्रुङ्ग नाच नाचिन्छ',
#  'सूचक छ',
#  'दर्ज गर्दछन्',
#  'भएका पृष्ठहरूको सूची',
#  'अवस्था आयो',
#  'बनाएँ यसमा यसरी',
#  'शिक्षा सेवा आयोग',
#  'सम्मान गरे',
#  'तैनाथ रहेको छ',
#  'त्रितङ्गु राजधन्यो भनेर',
#  'यो छाला मोहोरेर',
#  'अग्रेजी भाषामा प्रयोग',
#  'ग्रहण गर्ने उनी',
#  'बिक्री गर्न सुरु गरे',
#  'प्राप्त कलेज हो',
#  'सन्तुलित रहन्छन्',
#  'पार्नुपर्ने छ',
#  'त्यसैले उनलाई सानै',
#  'बनावट र चाल',
#  'अस्ट्रेलियाली आदिवासीहरूले',
#  'पेप्परमिन्ट लिनक्स एक',
#  'सुगमतापूर्वक जीवन व्यतीत',
#  'मध्य नेपालमा पर्दछ',
#  'यो व्यवस्था संविधानद्वारा',
#  'श्रेष्ठ र रमेश',
#  'रूपमा रहे',
#  'सुब्बा अमर बानियाँ',
#  'छ भने उनीहरूसित',
#  'इस्लामको स्वर्ण युग',
#  'पञ्चकुले दाङ',
#  'कहिल्यै प्रगति हुँदैन',
#  'यसको कलिलो मुन्टा',
#  'अनजानमा कसैलाई उपकार',
#  'यस नदीका सहायक',
#  'हुँदै जाँदा थप',
#  'बोथाले राजिनामा दिएपछि',
#  'तथा अन्य कर्मचारी',
#  'जस्तै काला गेडा',
#  'रूपमा बनेको अँध्यारो',
#  'त्यसको श्रेय जनताद्वारा',
#  'किरी क्षेत्रमा सुरक्षाकर्मीले',
#  'सहायक नदिहरूले एउटा',
#  'मलाई लाग्दछ मेरो',
#  'फ्रान्स च्याप्टर हेर्दै',
#  'मलाई सन्देश',
#  'गाउँ त्यागेर',
#  'कसैले पनि',
#  'बारेको जसताको छाना',
#  'दक्षिण कौशल जुन',
#  'नेपालीमा वनमाली निराकारको पत्रसञ्चयन यसको उदाहरण हो',
#  'कार्य प्रस्तुत',
#  'नामक पर्वतको काखमा',
#  'मूर्ती बनाएका थिए',
#  'आदि तत्त्वहरू पाइन्छ',
#  'महारत प्राप्त गरे',
#  'संसदका दुईटै सदनहरूका',
#  'भने कि उनलाई',
#  'राष्ट्रिय पार्टीले संविधान',
#  'सुधारकहरूमध्येका एक थिए',
#  'अवस्थित रहेको छ',
#  'छैनन् तर जसले',
#  'सुम्निमाको सृष्टि भएको',
#  'साथै अनलाइन सेवाले',
#  'थिएटर सञ्चालित छ',
#  'अन्यायको विरुद्धमा',
#  'विष्णुमती नामक दुई',
#  'बच्चाहरूको बोली समयमा',
#  'ओखर पाँगर चाँप',
#  'नलेखौँ बाँकी कुरा',
#  'गाउँ विकास समितिका',
#  'अमरभुमी नेपालको',
#  'आर्थिक विकासको गति',
#  'ज्ञानी बनी प्रातमा',
#  'यसको फलको आकार',
#  'निरुता सिंह नेपाली चलचित्र क्षेत्रको एक चर्चित अभिनेत्री हुन्',
#  'वटा नयाँ लेख',
#  'अनि बल्ल रूपले',
#  'त्यस्तै नेपालमा कम्युनिस्टहरूले',
#  'कुनै पनि चक्र',
#  'ज त जा',
#  'व्यापारमा एउटा स्वस्थ',
#  'नरकको प्राप्ति हुन्छ',
#  'संसारमा जति पनि',
#  'असम्भव हुनु हुँदैन',
#  'जो एक ताराहरूका',
#  'हुँदै गएको देखिन्छ',
#  'हत्या गर्न सफल भयो',
#  'पुरस्कृत हुने पोषण',
#  'पनि आँखाको जलन',
#  'कुरान सरिफभन्दा केही',
#  'विभिन्न विचार र स्वार्थको',
#  'ओलम्पिक खेलको सुरूआत',
#  'मूल्य अत्यन्तै बढी',
#  'परिवारमा अवस्थित विपदा',
#  'गर्नु भएको कान्तिपुरको',
#  'उनीसँग विवाहित पुरुषसँग',
#  'महिलाका लागि कार्यक्रम',
#  'रूपमा रहन्छ',
#  'पर्यटनका लागि पनि',
#  'क्षेत्रसँग जोडेका छन्',
#  'पनि प्रयोग गर्ने',
#  'नाइके बाख्रो',
#  'गोबर्धन पर्वतको पूजा',
#  'यस स्थलमा',
#  'पाल्पामा प्रजातान्त्रिक आन्दोलनका',
#  'भै रहेको थियो',
#  'देखेर मलाई कसैले',
#  'आवाजले सबैको मन',
#  'कोगन मृत्यु दण्ड',
#  'प्रज्वल क्याम्पस झापा जिल्लामा रहेको एउटा क्याम्पस हो',
#  'लोकोक्ती यहाँ सार्थक',
#  'वर्तमानमा',
#  'काम गर्दै गयो',
#  'यसको विभेद मूर्ति',
#  'केरल प्रान्त पर्यटकहरूमा',
#  'अवरोध जस्ता',
#  'मैले दुई जना',
#  'हेर्न चाहन्छौ भने',
#  'इलाहाबाद हल्दिए राष्ट्रिय',
#  'थिएँ तर आज',
#  'प्रहरी थाना थिए',
#  'लिमिटेड नेपाल राष्ट्र बैंकको',
#  'प्रकाशित भयो',
#  'कतिपय यस्ता नेपालीहरू',
#  'अहिलेसम्म प्रख्यात रहेको',
#  'आँखु नदी र समतल',
#  'आदिवासी जनजातिका',
#  'उनको त्यसपछिको',
#  'प्रति अगाध आस्था',
#  'पुरुष मरेकै कारणले',
#  'सत्तामा आइन्',
#  'यस फलको बीजमा',
#  'युकेशज्यू नमस्कार',
#  'पुत्रले पितालाई लेखेको',
#  'अग्लो स्थानलाई धुरा',
#  'नगर देशमा',
#  'संस्थापक श्री श्री रविशंकरले',
#  'रहँदा नै अर्जुनको',
#  'तिब्बतीहरू सन्धि गर्न',
#  'नेपाल महासचिव हुनुहुन्थ्यो',
#  'विद्यालयलाई मानिन्छ',
#  'रचित उपलब्ध छ',
#  'वेला उन घर',
#  'पुनः त्यो पृष्ठ',
#  'साम्राज्यवादी असुरहरूको विरोधको',
#  'समयबाट अलिकति',
#  'उनलाई हेर्न र भेट्न',
#  'अञ्चलमा विभाजन गरियो',
#  'भुपालेन्द्र मल्ललाई स्थापित गर्ने',
#  'सरस्वती',
#  'अन्यमा रोटको पनि',
#  'हुने कुरा उल्लेख',
#  'पैटरसनको प्रसिद्ध कविता',
#  'स्थल मानिन्छ',
#  'लाग्दा वा काट्ता',
#  'जित दर्ता गर् यो',
#  'क्षेत्र भेरी अञ्चलको',
#  'कोट साडी ब्लाउज',
#  'कमिटीमा रहेर',
#  'वार्ताले तपाईँलाई',
#  'मुखमा रहेको सानो',
#  'अध्ययन अनुसन्धानमा छ',
#  'पारित भएमा',
#  'सदरमुकाम जिल्ला',
#  'अथवा बोलीको बारेमा',
#  'बनेको अमेरिकी चलचित्र हो',
#  'कवि भानुभक्तको जीवनचरित्र',
#  'पदहरूमा रहँदै बाग्लुङ',
#  'टेकेर हिँड्ने गर्छ',
#  'बरू नाकभित्रबाट माथि',
#  'रूपले अस्ट्रेलियाको खोज',
#  'प्रसारको कारण हुन्छ',
#  'नेपाली मेरो मातृभाषा',
#  'दान गर्न',
#  'गोठालाहरूले पाल्ने गर्थे',
#  'र यदाकदा जातीय',
#  'कसरी गर्न सकिन्छ',
#  'अभिभावकका छोराछोरीको अधिकारको',
#  'नक्कली मानिस',
#  'राम्रोसँग सुकाउनु पर्दछ',
#  'समुद्रमा खस्छ',
#  'सक्छ तसर्थ इमेल',
#  'केही समयका लागि',
#  'देवीका सात बहिनीमध्ये',
#  'सगरमाथा अञ्चलको मध्य',
#  'रूपमा समेत काम',
#  'मानिसहरू सोङचान गाम्पोको',
#  'मुख्य अभिलक्षण हो',
#  'अघि लाग्नुपर्ने एवं',
#  'अर्जुनको रूखलाई स्वाति',
#  'बनाउन पाएनन्',
#  'झिल्को सामुन्ने सानी',
#  'खोला र लोहोरे खोलाको',
#  'पूजा गरिन्छ',
#  'हुन लाग्यो',
#  'कुकुर पशु भएतापनि',
#  'जिन अनेक पिँढिहरूसम्म',
#  'कार्यरत हुनुहुन्छ',
#  'प्रलयको दिन भन्दछन्',
#  'मेरो मामाको पनि',
#  'हिन्दू योद्धा सन्त',
#  'उत्परिवर्तनहरूको महत्त्वको निम्नलिखित',
#  'भौगर्भिक प्रक्रियाहरूको प्रतिरोध',
#  'शीर्षनेता खनाल',
#  'र अशान्ति बढ्ने छ',
#  'आजकल आनुवंशिकीको',
#  'यो नदीको अन्तिम',
#  'कमलामाई र गौतमी',
#  'यसमा भएको',
#  'धाराको रूपमा लिने',
#  'खेली आफ्नो व्यावसायिक',
#  'श्रेष्ठले प्रेमबहादुर कङ्साकार',
#  'राजधानी सिनिङ हो',
#  'प्रयोग गर्दा तथा',
#  'उदाहरणका लागि भारतको',
#  'अल्झेर उनीहरूले केही',
#  'नयाँ नेपाल लघु',
#  'रक्तक्यान्सर भयो',
#  'बोधक शब्दको',
#  'यसको लागि पुरानो',
#  'भने खेतीयोग्य जमिन',
#  'मौनका रूपमा गरे',
#  'ठूला हरिया पात',
#  'भुटानका राजा',
#  'ढाकाटोपी घरेलु तानमा',
#  'उपत्यकाको तेस्रो केन्द्र',
#  'राष्ट्रपतिको पदभार सम्हाले',
#  'मानिसहरू यति राम्रो',
#  'एकदेखि स्वयम् का पुत्र भरतलाई अयोध्याको राजगद्दी तथा अर्कासित रामलाई चौध वर्षको वनवास',
#  'साउथ वेल्समा सङ्घीय',
#  'नेवार दनुवार दमाई',
#  'ध्वनिलाई सुन्न सक्छ',
#  'र जनजातिको अधिकारलाई',
#  'प्रतिनीधित्व गरेको छ',
#  'यसमा पनि पैसाको',
#  'ख तार्किक निबन्ध',
#  'नाउँ दर्ता गरेको',
#  'देखाउन पछि परेका',
#  'मेची कोशी र सगरमाथा',
#  'हार्मोन दिनको लागि',
#  'कुल जनसङ्ख्याको',
#  'थियो तर बेलायती',
#  'राख्न सक्नु हुन्छ',
#  'हुन्छ त्यसरी नै ज्योतिषमा',
#  'थिए तैपनि तिनले',
#  'हुन आउँछ',
#  'केही दिन बसेछन्',
#  'करोडपतिको स्थितिबाट',
#  'यसको तौल प्रतिदिन',
#  'कामको सुविधा पनि',
#  'सुप्रिम कोर्टमा मुख्य',
#  'यसमा जानुहोस्',
#  'दुःखमाथि दुःख थप्ने',
#  'सङ्ख्या हुन्छन् एक',
#  'हजारेले सोमबार यहाँ',
#  'बिजुली र पानीको',
#  'समाजको दृष्टिमा प्रत्येक',
#  'हो र भविष्यमा',
#  'सीमान्तकृत सन्थाल जाति',
#  'बसाइँ सरेको समयलाई',
#  'शासन गरेका थिए',
#  'पुरुष सन्तानहरूमा नै',
#  'देवीलाई अष्टमण्डपमा राखेर',
#  'छत्रगन्ज अर्घाखाँची जिल्लाको',
#  'रूपमा परिचित मुख्य',
#  'भाषाको भन्दा पनि',
#  'आफ्नो सेवाहरू दिए',
#  'यो सहरको स्थापना',
#  'स्थापित मन्त्रालय हो',
#  'कारण उन्नाइसौँ शताब्दीको',
#  'गरेको उनी बताउँछन्',
#  'चोभारको गल्छीबाट',
#  'शसस्त्र विद्रोहकै क्रममा',
#  'व्यवस्था गर्दा',
#  'समूहमा युवती',
#  'नुन पनि नखाने',
#  'प्रकाश कोइराला',
#  'उन्नाइसौं शताब्दीमा',
#  'नभएको गहिरिएर अध्ययन',
#  'गरिएको थियो र पछि',
#  'गरिन्छ र यिनको मतलाई',
#  'मताधिकार प्रदान गर्ने',
#  'आकर्षित गर्छ',
#  'गरिराखेको हुन्छ',
#  'दिशाको ज्ञान गराउँछ',
#  'पारिएको अर्थीमा दक्षिण',
#  'तर पनि पृथ्वीका',
#  'प्रक्रिया काम कर्तव्य',
#  'पुत्रहरूले त्यसलाई फेरि',
#  'असाध्यै चिन्ता लाग्छ',
#  'निरन्तर प्रभावसाली प्रदर्शनहरूको',
#  'स्कुलमा शिक्षकको जागिर',
#  'बिलबोर्ड डिजिटल गीतहरूको',
#  'सक्दछन् भनी मान्दैनथे',
#  'सिमलबोटका स्थायीबासी रानाले',
#  'महत्त्व पनि छ',
#  'लागि प्रेरित गर्छ',
#  'यस प्रकार कौरवहरूले',
#  'प्रक्रिया हो जसले',
#  'अनि उनले भुइँमा',
#  'हेर्न लायक छन्',
#  'झुला गाविस राजनैतिक',
#  'काण्डलाई चुडाउँदा दुध',
#  'खती हुने हुन्छ',
#  'उपायहरू अपनाउने छन्',
#  'प्रावधानहरू पर्छन्',
#  'उनले अदलतको फैसलालाई',
#  'कुँवरले स्थापना',
#  'त्यसपछि कुमारी सिनेमा',
#  'लगायत भारतका हिन्दु',
#  'हुनाले यहाँ बुद्ध',
#  'यस्तो पनि भनिन्छ',
#  'त्यसै वर्ष प्रधानमन्त्री',
#  'बोलेको बुझ्छ',
#  'मातृभूमिको सेवा गरेको थियो',
#  'आदिको दबावका कारण',
#  'मद्दत गर्नुभयो',
#  'भाइको हड्डी हेर्न',
#  'डी सी सरकारले',
#  'मूल पटना हो',
#  'यो पुस्तक लेखनाथले',
#  'अब एकता देखाउने',
#  'परिवर्तन एउटा नेपाली',
#  'चौतारा नगरपालिका',
#  'दुर्गाभवानी नेपालको',
#  'पढ्न सकेनन्',
#  'अभाव भयो',
#  'देखापरिसकेको थियो',
#  'डन्डी समूहका खेलाडीहरूले',
#  'चलचित्रमा समलिङ्गीहरूको',
#  'भुपालेन्द्र मल्ललाई स्थापित गर्ने',
#  'धेरै खतरनाक भएरै हो',
#  'यो दिन',
#  'सांस्कृतिक र राजनीतिक',
#  'अनुपात छ',
#  'द्रोहको अभाव',
#  'गान्धीको सत्याग्रह आन्दोलनको',
#  'निर्वाचित अधिकारी',
#  'आदिवासीहरूले अस्ट्रेलियाली',
#  'गोल्ड र लुनार',
#  'कम मान्छे मात्र',
#  'गरी मेटाउन पर्न सक्छ',
#  'वर्षाका महिनाहरू बाहेक',
#  'पूरा अनुहार धुन्छन्',
#  'मुक्त गर्छ र अड्डाबाट',
#  'नपाइने भएको हुँदा',
#  'सिजीले सेयर बजारलाई',
#  'आक्रमण गरी मोरङ',
#  'आत्मविश्वासको अभाव थियो',
#  'गोरा अफ्रिकन',
#  'सूचना प्रचार गरियो',
#  'यो रोगलाई मृगी',
#  'कुकुरलाई पनि',
#  'वरको रूख आदि',
#  'मलेखु मजुवा पुष्पलाल',
#  'विश्व युद्धका बेला',
#  'केन तथा छान्दोग्य',
#  'सिडी डिभिडीको',
#  'केवल सात वर्षको',
#  'गण्डकी धवलागिरी र',
#  'सम्भावना थियो',
#  'अहमदाबाद प्रमुख आधार',
#  'देशहरूका मानिसहरूलाई',
#  'कास्की जिल्लामा पर्दछ',
#  'मैले केही दिन',
#  'विकास क्षेत्रको बागमती',
#  'भगतद्वारा लिखित',
#  'वेदान्तिहरूका अनुसार',
#  'उपनिषद्ले गुरु शिक्षा',
#  'यी भाषाहरूलाई नेपाली',
#  'सर्वश्रेष्ठ खेलाडी',
#  'ईश्वरका साथ आत्मद्रव्यहरूको',
#  'सजिलो तरिकाको रूपमा',
#  'लामा गुरूहरू शेर्पा गाउँ',
#  'अर्को पक्ष',
#  'यो विभाग नगरका',
#  'अझैसम्म कमै मात्र',
#  'पिडोको ढिँडो पकाएर',
#  'रहेको गोकर्ण सफारी',
#  'निर्मलले तपाईँलाई क्रिसमसको',
#  'अथवा सामानमा मानिस',
#  'उनको चौथो पुस्ता',
#  'अधिक उचाइको कारण',
#  'पचमुखे',
#  'त्यसैले नक्षत्रका अधिदेवताका',
#  'ऋण जसको दुई',
#  'उचाइमा अवस्थित छ',
#  'यो प्रश्नमा सायद',
#  'एक साथ अभिनय गरे',
#  'उनका उपन्यासको वैचारिक',
#  'नायक रमित ढुङ्गाना',
#  'उनीहरूकै काम थियो',
#  'उपत्यका नेपालको केन्द्र',
#  'ऐसडाउनको आफ्नो खोजको',
#  'प्रमुख दुई',
#  'माध्यमबाट हुन्छ',
#  'विश्व इन्टरनेट सञ्जालमा',
#  'भनेर विश्वस्त छौँ',
#  'लमही भालुवाङ तथा',
#  'पीडित भए',
#  'असावधानी के देखाएका',
#  'किनभने तिनीहरू एक',
#  'कर्नेलको घोडा साहित्यकार',
#  'पुरातत्त्वका ज्ञानहरू बटुले',
#  'राहु ग्रह व्यक्तिको कुण्डलीमा',
#  'र सुनुवार छन्',
#  'हिजो मेरो ब्राउजरको',
#  'हालैका खगोल भौतिक',
#  'अलग प्रकारको माटोमा',
#  'मैले जीवनमा एउटा',
#  'पहल हुने',
#  'रूपमा प्रख्यात भए',
#  'थियो भने पछि',
#  'निर्मित हातले चलाइने',
#  'सङ्ख्यामा रहेको यी चराका',
#  'चेपिएको यो समाज',
#  'धेरै राम्ररी प्रयोग',
#  'सुनको थियो र अहिले',
#  'भाषा संस्कृति',
#  'लुईस लाचेनल',
#  'लागि चाहिने किसिमका',
#  'गोगने मकवानपुर जिल्लामा',
#  'बनाउने प्रविधिको विकास',
#  'सार्वभौम राष्ट्र राज्यहरूको',
#  'उपाय अपनाउनु पर्छ',
#  'शिवलिङ्ग स्थापना गरिएको छ',
#  'पहिलो कम्प्युटर भइरस',
#  'कविता सङ्ग्रह',
#  'विनोद बनाइदिन्छ',
#  'जुन यसको डाटा',
#  'इतिहासविदहरू बताउँछन्',
#  'त्यसको उत्तर न',
#  'यो प्रयोगकर्तासँग सम्बन्धित',
#  'उनले पाँच चौका',
#  'राखिदिएको खण्डमा धेरै',
#  'रक्सी पनि गौतमको',
#  'रातभर जाग्राम बस्छन्',
#  'मार्फत् महाराजाधिराजमा जाहेर',
#  'ठाउँमा स्पेनिस मातापिताका',
#  'मुख्य मुख्य अन्तर्राष्ट्रिय',
#  'आन्दोलनमा उत्रियो',
#  'पाँचैवटा आँखाबाट बराबर',
#  'लिएर मात्र गर्नुहोला',
#  'पर्वतारोहण इतिहासको तालिका',
#  'अन्य मनुष्यहरूलाई बन्दी',
#  'एक महिनासम्म सत्तामा',
#  'प्रथम हुनु भए',
#  'समय बित्दै जाँदा',
#  'उपेन्द्र यादव मधेस',
#  'इस्लामी अतिवादीहरूले पश्चिमी',
#  'त्यसरी हेर्नको लागि',
#  'जिल्लाको जनकपुरमा अवस्थित',
#  'रहेका यस्तो धेरै',
#  'देश यमनको भाग हो',
#  'यही पानी माथि',
#  'जना जोगी आइपुगे',
#  'अन्तरिक्षीय अभियान्त्रिकी वा',
#  'नवलपरासी जिल्लाको',
#  'प्यागोडा शैलीका टुँडालको',
#  'उक्त लेखमा मैले',
#  'रोजगार प्राप्त भयो',
#  'रूपमा घोषणा गरिएको छ',
#  'डेल्फीका मानिसहरूको लोभीपन',
#  'टाइम म्यागेजिनले अमेरिकालाई',
#  'यो उपत्यका पर्दछ',
#  'निर्गुण ब्रह्म ज्ञान',
#  'स्नातक अध्ययन गरेका',
#  'आमाको पुनर्जीवन मागे',
#  'नामहरू लेख्दै थिएँ',
#  'र नेपाली विकिमा सक्रिय',
#  'जसलाई उनले आठ',
#  'रहेको यस नदीमा',
#  'धेरै भागहरूमा',
#  'नमो बुद्ध क्षेत्रको',
#  'हुनाले यस दिन',
#  'आज काटेको प्याज',
#  'उक्त चलचित्रमा',
#  'यो ठाउँ तरकारी',
#  'अध्ययन गर्नको लागि',
#  'हुने खोल जिल्लालाई',
#  'धेरै सुन्दर व्यक्तिका',
#  'पहिले पहिले मार्सी',
#  'उनीहरूले यहाँको बारेमा',
#  'अहिंसक सङ्घर्ष जारी',
#  'यात्राको आवश्यकता हुन्थ्यो',
#  'गरिएको वर्णनप्रधान निबन्धलाई',
#  'सम्राट यन्त्र सूर्यको',
#  'अन्य प्रधान सहरहरू',
#  'जसलाई भावर क्षेत्र',
#  'उल्लेखित उपथरहरूबाट नै',
#  'उनलाई अग्रराज महिषीका',
#  'डियर जोन निकोलस',
#  'मान्छेहरूलाई रेडियो',
#  'किबोर्ड लेआउट',
#  'सेनाले बारम्बार दुख',
#  'समान गर् यो',
#  'पूर्वाञ्चल विश्वविद्यालय भारतीय',
#  'घोषित गरेका छन्',
#  'विकास भएको काठमाडौँ',
#  'साथ आफ्नो सम्बन्धहरूलाई',
#  'कमै रहन्छ',
#  'कूल क्षेत्रफल वर्ग',
#  'यात्राका कारण पैदा',
#  'लोप भएको ग्रन्थहरूबाट',
#  'समाज शोषक र',
#  'पछि विभिन्न समहरूमा',
#  'उनका हजारौं समर्थक',
#  'मलामीहरूले हात हातमा',
#  'श्रीमान् भवानी गौतम ज्यू',
#  ...]

# %%
len((data_set_list_total[:-1]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-91d59651b796> in <module>
# ----> 1 len((data_set_list_total[:-1]))
#
# /opt/conda/lib/python3.8/site-packages/datasets/arrow_dataset.py in __getitem__(self, key)
#    1924     def __getitem__(self, key):  # noqa: F811
#    1925         """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 1926         return self._getitem(
#    1927             key,
#    1928         )
#
# /opt/conda/lib/python3.8/site-packages/datasets/arrow_dataset.py in _getitem(self, key, decoded, **kwargs)
#    1909         formatter = get_formatter(format_type, features=self.features, decoded=decoded, **format_kwargs)
#    1910         pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 1911         formatted_output = format_table(
#    1912             pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    1913         )
#
# /opt/conda/lib/python3.8/site-packages/datasets/formatting/formatting.py in format_table(table, key, formatter, format_columns, output_all_columns)
#     529     python_formatter = PythonFormatter(features=None)
#     530     if format_columns is None:
# --> 531         return formatter(pa_table, query_type=query_type)
#     532     elif query_type == "column":
#     533         if key in format_columns:
#
# /opt/conda/lib/python3.8/site-packages/datasets/formatting/formatting.py in __call__(self, pa_table, query_type)
#     282             return self.format_column(pa_table)
#     283         elif query_type == "batch":
# --> 284             return self.format_batch(pa_table)
#     285
#     286     def format_row(self, pa_table: pa.Table) -> RowFormat:
#
# /opt/conda/lib/python3.8/site-packages/datasets/formatting/formatting.py in format_batch(self, pa_table)
#     319
#     320     def format_batch(self, pa_table: pa.Table) -> dict:
# --> 321         batch = self.python_arrow_extractor().extract_batch(pa_table)
#     322         if self.decoded:
#     323             batch = self.python_features_decoder.decode_batch(batch)
#
# /opt/conda/lib/python3.8/site-packages/datasets/formatting/formatting.py in extract_batch(self, pa_table)
#     143
#     144     def extract_batch(self, pa_table: pa.Table) -> dict:
# --> 145         return pa_table.to_pydict()
#     146
#     147
#
# KeyboardInterrupt:

# %%
len((data_set_list_total[-1:]))
# Out:
# 1

# %%
# common_voice_train = concatenate_datasets(data_set_list_total[:-1])

# common_voice_train = concatenate_datasets(data_set_list_total[5:6])
common_voice_train = data_set_list_total
common_voice_test = common_voice_train

# %%
# # common_voice_test = concatenate_datasets(data_set_list_total[-1:])

# common_voice_test = concaatenate_datasets(data_set_list_total[5:6])

# %%
common_voice_train
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 6626
# })

# %%
common_voice_test
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 6626
# })

# %%
common_voice_train
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 6626
# })

# %%
# from huggingface_hub import notebook_login
# notebook_login()

# %%
common_voice_train
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 6626
# })

# %%
# repo_name = "wav2vec2-large-xlsr-300m-nepali"

# %%
# tokenizer.push_to_hub(repo_name)

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
# wer_metric = load_metric("wer")
# wer_metric.compute(predictions= "I am a boy", references="I am a boy")

# %%
# def compute_metrics():
    
# transcription = processor.batch_decode(logits.numpy()).text
# transcription[0].lower()

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
#     pred_ids = np.argmax(pred_logits, axis=-1)

#     pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

#     pred_str = processor.batch_decode(pred_ids)
    transcription = processor.batch_decode(pred_logits).text
    print("Transcriptions is", transcription)
    pred_str= transcription[0].lower()
    print("pred_str is",pred_str)

    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)
    print("label_str is", label_str)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
len(processor.tokenizer)
# Out:
# 62

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-xls-r-300m", 
    attention_dropout=0.0,
    hidden_dropout=0.0,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.0,
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer),
)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-xls-r-300m were not used when initializing Wav2Vec2ForCTC: ['quantizer.codevectors', 'project_q.weight', 'project_hid.bias', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'project_q.bias', 'project_hid.weight']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-xls-r-300m and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_extractor()

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir="./tst_lm",
  group_by_length=True,
  per_device_train_batch_size=16,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=10,
  gradient_checkpointing=True,
  fp16=True,
  save_steps=20,
  eval_steps=5,
  logging_steps=20,
  learning_rate=3e-4,
  warmup_steps=500,
  save_total_limit=2,
  push_to_hub=False,
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=common_voice_train,
    eval_dataset=common_voice_test,
    tokenizer=processor.feature_extractor,
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 6626
#   Num Epochs = 10
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 2
#   Total optimization steps = 2070
#     <div>
#
#       <progress value='6' max='2070' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   6/2070 00:07 < 1:01:10, 0.56 it/s, Epoch 0.02/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='829' max='829' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [829/829 03:12]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 6626
#   Batch size = 8

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to wav2vec2-large-xlsr-300m-nepali
# Configuration saved in wav2vec2-large-xlsr-300m-nepali/config.json
# Model weights saved in wav2vec2-large-xlsr-300m-nepali/pytorch_model.bin
# Configuration saved in wav2vec2-large-xlsr-300m-nepali/preprocessor_config.json
# Dropping the following result as it does not have all the necessary fields:
# {}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 3.37k/1.18G [00:00<?, ?B/s]
# To https://huggingface.co/prajin/wav2vec2-large-xlsr-300m-nepali
#    2889e67..e7edbaf  main -> main

# %%
# trainer.save_metrics(all, metrics)
