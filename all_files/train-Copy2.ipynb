# %%
import os
import torch
from sklearn.model_selection import train_test_split
from datasets import load_dataset, load_metric,Dataset,concatenate_datasets,set_caching_enabled, ClassLabel
import pandas as pd

import random
from IPython.display import display, HTML

import json
from transformers import Wav2Vec2CTCTokenizer,Wav2Vec2ForCTC,Wav2Vec2Processor,Trainer,TrainingArguments,Wav2Vec2FeatureExtractor

import re
set_caching_enabled(False)

import soundfile as sf
import torchaudio


import IPython.display as ipd

import numpy as np
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

from tqdm import tqdm
import torch

# Set environment variables
os.environ['WANDB_DISABLED '] = 'True'

import warnings
warnings.filterwarnings('ignore')

# %%
# !ps -ef

# %%
import logging
import transformers
transformers.logging.get_verbosity = lambda: logging.NOTSET

transformers.logging.get_verbosity()
# Out:
# 0

# %%
import datasets
datasets.logging.get_verbosity = lambda: logging.NOTSET

# %%
tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %%
feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)

# %%
processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %%
import glob 
data_dir  = "/workspace/data_processed/*"
data_dir_list = glob.glob(data_dir)
data_dir_list.remove('/workspace/data_processed/5')

# %%
data_dir_list = ['/workspace/data_processed/26',
 '/workspace/data_processed/13',
 '/workspace/data_processed/2',
 '/workspace/data_processed/7',
 '/workspace/data_processed/14',
 '/workspace/data_processed/24',
 '/workspace/data_processed/3',
 '/workspace/data_processed/38',
 '/workspace/data_processed/28',
 '/workspace/data_processed/16',
 '/workspace/data_processed/30',
 '/workspace/data_processed/36',
 '/workspace/data_processed/4',
 '/workspace/data_processed/18',
 '/workspace/data_processed/29',
 '/workspace/data_processed/8',
 '/workspace/data_processed/31',
 '/workspace/data_processed/27',
 '/workspace/data_processed/6',
 '/workspace/data_processed/10',
 '/workspace/data_processed/21',
 '/workspace/data_processed/15',
 '/workspace/data_processed/35',
 '/workspace/data_processed/9',
 '/workspace/data_processed/25',
 '/workspace/data_processed/22',
 '/workspace/data_processed/33',
 '/workspace/data_processed/20',
 '/workspace/data_processed/12',
 '/workspace/data_processed/39',
 '/workspace/data_processed/1',
 '/workspace/data_processed/37',
 '/workspace/data_processed/17',
 '/workspace/data_processed/11',
 '/workspace/data_processed/19',
 '/workspace/data_processed/34',
 '/workspace/data_processed/23',
 '/workspace/data_processed/32']

data_dir_list.remove('/workspace/data_processed/5')

# %%
data_set_list_total = []
for i in range(len(data_dir_list)):
    common_voice_val = Dataset.load_from_disk(data_dir_list[i])
    data_set_list_total.append(common_voice_val)

# %%
len(data_set_list_total)
# Out:
# 38

# %%
len((data_set_list_total[:-1]))
# Out:
# 37

# %%
len((data_set_list_total[-1:]))
# Out:
# 1

# %%
common_voice_train = concatenate_datasets(data_set_list_total[5:6])
common_voice_train
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 4563
# })

# %%
common_voice_test = concatenate_datasets(data_set_list_total[5:6])

# %%
common_voice_train
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 4563
# })

# %%
common_voice_test
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 4563
# })

# %%
common_voice_train
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 4563
# })

# %%
# from huggingface_hub import notebook_login
# notebook_login()

# %%
common_voice_train
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 4563
# })

# %%
# repo_name = "wav2vec2-large-xlsr-300m-nepali"

# %%
# tokenizer.push_to_hub(repo_name)

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
wer_metric = load_metric("wer")

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    print("pred_str", pred_str)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)
    print("label string", label_str)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
len(processor.tokenizer)
# Out:
# 62

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-xls-r-300m", 
    attention_dropout=0.0,
    hidden_dropout=0.0,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.0,
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer),
)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-xls-r-300m were not used when initializing Wav2Vec2ForCTC: ['project_q.bias', 'quantizer.weight_proj.bias', 'project_q.weight', 'quantizer.codevectors', 'quantizer.weight_proj.weight', 'project_hid.bias', 'project_hid.weight']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-xls-r-300m and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_extractor()

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir="./test",
  group_by_length=True,
  per_device_train_batch_size=1,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=2,
  gradient_checkpointing=True,
  fp16=True,
  save_steps=2,
  eval_steps=2,
  logging_steps=2,
  learning_rate=3e-4,
  warmup_steps=500,
  save_total_limit=2,
  push_to_hub=False,
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=common_voice_train,
    eval_dataset=common_voice_test,
    tokenizer=processor.feature_extractor,
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 4563
#   Num Epochs = 2
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 2
#   Total optimization steps = 4562
#     <div>
#
#       <progress value='5' max='4562' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   5/4562 03:57 < 100:12:16, 0.01 it/s, Epoch 0.00/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2</td>
#       <td>22.124300</td>
#       <td>27.401600</td>
#       <td>1.000029</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='76' max='571' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 76/571 00:19 < 02:11, 3.77 it/s]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 4563
#   Batch size = 8
# pred_str ['झबझनझुझुझसऊझऊचड', 'ऊझखझबझुझुझुझुझुझुुझुसऊचतचतऊचड', 'झबझनझबझबझबझबझनबझनबझनझनझनझबझबझनझुझुझुझबझबझनझबझुझुझुझड', 'झबझुझुझऊड', 'ऊझबझबझझबझबझनझनबझनझुझुझुऊतचड', 'झुझुझबऊझबझनझुझुझबझबझुबुझनझुचड', 'ऊझनझबझबझबझनझबझुझुझुचऊचऊड', 'झुझुझबझनझुझुझुझुझुझचऊचऊड', 'झबझबझबझबझबझुझुझुझुचतचड', 'झबझबझनबझुझुझसऊचऊड', 'ऊबझुझुझुझबझनझुझनझुझुझुझुझबनझनबझुझुझुनझबझबझबझुझनझनबझुझुझुझुझुझुझुझुनझबझुझुझङझबझबझुझुझड', 'ऊझबझबझबझबझुझुझुझसऊड', 'झनबझबझुझबझनझनबझनबझनझनबझुझुझुऊड', 'झुझुझनझुझुझुझुझुझुझुझुझुझुझुझुझुझड', 'ऊझुझबझुझबझनझुझबझनझुबझनबझनझनझुझुझऊड', 'झबझुझनुझऊझबझबझुझुझुझुझुझुचचड', 'सझबझबझबझबझबझबझुझबझबझनझबझबझबझबझुझुझुझऊड', 'ऊबझबझझबझबझङझबझुझङझबझुझुझङझुबझबनझनझुुझऊझऊचड', 'ऊझबझबझबझनबझनझबझुझुझऊड', 'ऊझबझबझबझनझुझुझुझुझुझऊड', 'ऊबझबझुझुझुचतऊचऊड', 'झऊबझबझबझुझुझुऊचऊड', 'ऊझनझुझसऊचऊड', 'बझबझुझुझबझुझुझुबझुबझुबझबझबझबझबझबझबझुझुबझुझुबझबझबझबझुझबझुबझुझबझुझुबझबझबझुझअझुझुझड', 'ऊझुबझबझुझबझबझबझुझुझुबझनबझुझुझुचऊचड', 'झबझबझनझबझबझनझुझुझङझुझुझुझुझुझुझबझबझबझबझबझबझनझबझुझुझुझुबझबझनझुझुझुझड', 'ऊझनझबझमझबझुनझुझुझुझुसऊड', 'ऊझुझुबझुबझबझुचऊतचतचड', 'ऊबझबझबझबझबनबनबझबझबझङझबझुबझुझुझबझुझबझबझनबझबझ
# label string ['अब अति', 'प्यान्ट', 'स्थान रेडियोको नियोजक लागि मात्र थियो', 'किस्ट', 'नागरिक शाहको नाम हो', 'त्यो नाम करार', 'मैले रेडियो', 'नेपालमा', 'एउटा नामै', 'दुईटा नाम मेरो भयो', 'त्यसैगरी धेरै ठाउँमा मान्छेहरूले क्वेस्ट रेजा एउटा मान्छेको दुईटा नाम कसरी हुन्छ', 'के रिक्वेस्ट गर्नु भने', 'मलाई माले', 'अवधि एकैछिन जुलाईमा यता बैतडी किरण मन्दिर नगरेर लिएर जान्छु जान चाहन्छु लाई बाल्यकाल कसरी', 'हरसाल परिवार बिरिङ द न्युज', 'क्यान यो', 'यसका हामी एउटा हालको अनुरोध भने', 'चराको नाम के होला त भन्न अडिसन', 'नेपाली नाम छ मेरो चिनको नाम छ', 'माइली तपाईँको नेपाली नाम छैन', 'भन्ने', 'बल कार्यक्रमले', 'यो लक डाउनले', 'दिएको छ के पुष्टि   चाडबाड  समष्टिको नाम', 'जब त्यसको पनि', 'कुरा पनि आएको थियो पाइला स्रोतहरू पनि  नयाँ', 'उहाँको वर्ष शुभ', 'उहाँको उच्चारण', 'ठेक्का पहिलो दिन रहेछ उहाँले नर्स पनि हुनुभयो', 'रयल गाविसमा  त्यतिबेला एउटा फिट ब्याक आइडिया हुने', 'जय प्रोग्राम लिसा छु', 'लासमा लाग्यो धर्म लाग्यो', 'यसपछि अलिकति मैले आफूलाई ट्रेड गरे', 'भन्यो कि', 'विशेषमा गल्ती पनि भएको हो', 'त्यतिबेलाको भने', 'पुराना फ्रान्स हरू', 'गरेपछि संसारमा गयो', 'पिपला लिनक्स', 'त्यतिबेला आइस गर्न', 'जब तिम्रो त्यो सोच्ने अन गर्छ', 'प्रो ग्रामको सबै डिस्क सर भयो', 'साथ  गए तयारी थियो', 'स्काई गर्नुहोस् र यो भन्दै अब देखि एउटा कुरा मुख्य  चाहनु सुन्तले याद गर्नुभएकी भएन', 'उहाँलाई छैन अस्तु प्रसन्न प्रसन्न लाई उहाँको छोरालाई मेमे पठाएको थे उसको साइत बिहे', 'टेलिया टाइम', 'टिमबाट देवलमा', 'भन्थ्यो हुन्थ्यो', 'के देखि अब', 'भयो अरू राम्रो कार्यक्रम', 'आरम्भमा के भने अमिलो मेडिकल म्यान क्लस्टरमा मिडिया', 'मलाई त्यो एफएम त्यसपछि', 'एफएमको पहिला कस्तो मलाई गोलाको एफएम ले गोलाको तिमीले गोलाको हो', 'यस्तो मान्छे त्यस्तो क्रिस छ तपाईँको एफएम सुरु भएपछि कुनै फलले बोलाउन हजुरलाई', 'अभियानहरूको', 'पाँच मिनेटको थियो सेटिङ सेन त्यो  लामो', 'केजी', 'बढी', 'दी पिपल फल सुट', 'पाँच मिटरभन्दा माथि त्यसपछि त', 'जुन पनि हेरे कतिले जुन भन्नुभयो म पनि धेरै मैले  जुम्ली पनि सपोर्ट गर्दैन', 'सैनिक', 'लिन्डन एसिड', 'गर्दछ', 'गर्दा पछि मैले तयारी कोस्ट गर्ने', 'केरलका', 'टोन्ड', 'त्यसमा के विश्वास गर्थे', 'गर्नु पर्थ्यो', 'जित', 'मलाई करेन गरेर त्यसको स्पिरिट माल हुँदैन  स्केल स्पेस', 'कस्तो हुन्थ्यो यहाँ टुक्रा', 'पनि सन्', 'प्रदर्शनी टाइ होल्ट', 'हाम्रो काम पनि मर्ने ट्रेनिङ', 'ट्रेनहरूको रूपले पछि रिसाएको', 'अर्को रूपको   मलाई', 'त्यसको  पति भएन', 'टाइम छ', 'तिनले गर्दाखेरि', 'त्यसैले मिलाएर जानु अत्यन्त', 'दिउँसो रेडियो हुन्थ्यो', 'म सात पुष्प जाने हुन्छ', 'त्यसपछि रेडियो', 'तर गरेको टाइम्स साझी बेलुकी', 'टाइम डिभाइस गरे', 'निकै राम्रो काम विराज', 'लाई प्रोग्राम यस्तो घटेको चिसो भने', 'हुन्छ लागि प्रोग्राम', 'यस्तो रमाइलो भएर धेरै कुरा सिके दाजुभाई मैले आजबाट', 'खोजी गर्न खोल्छ कसैले डकुमेन्ट्री बनाउने खोल्छ भने त्यो योगदान गरेको कुराहरू', 'मलाई तपाईँले जसरी साथ दिनुभएको त्यसरी नै साथ छायो युद्ध बसी छायो र मैले एउटा के थापा थाहा छ', 'भोजन हुन्थ्यो गाद कमेन्ट हरू अहिले तपका फोटो जस्तै', 'बियो टुक्रा नक्सा पनि भने ग्राबिल टुक्रालाई मन्दिर', 'मलाई', 'यदि तपाईँ सहयोग गर्न चाहनुहुन्छ भने त्यो टारहरू तर्साउन नबिन होला त्यस्तै', 'चिनेजानेका अर्कै उहाँको वास्तवमै', 'राम्रो सञ्चार हकलाई आउँदैन', 'बन्टिङ', 'तिर किराती जना केटाहरू भजन कम गर्दथे', 'सिक्न भर्ना अझ', 'मान्छेहरूको लागियो लगाउने', 'अझै पनि नट', 'राजाका जेल कलेजी', 'रचना', 'वसमाजिक तिम्रो वशमा पनि  युवा दुई ग्रेट', 'प्रिफेक्चरमा सँग पनि आउट श्रेय माफि युद्धको भएनन्', 'कोर्स अल द फाइनान्स टाइम्स विचार सेन्ट इन्टु पाँच', 'स्टुडियो अपरेट नेपाल', 'वेल्स टु दलाइ क्याट प्रोग्राम', 'म्युजिकल वरको यत्रो तपाईँले गर्दनमा म्युजिकल वरको गर्नु भएन भन्दै यहाँ उनले हाम्रो राज मर्जी न्युजिल्यान्ड बाट हेर्नुहुन्छ दाइ म्युजिक वरको पनि जान प्लेज भन्ने हुनुहुन्छ', 'न्युज मात्रै खर्चबाट रहेन', 'पूर्व एड्ड्रेस गर्ने एउटा तरिका हो', 'राखेर स्रोताहरूलाई एउटा आधार', 'टाउको नेरा र', 'नै यस', 'समेत नेपाल', 'यसरी  पनि', 'अल्लो जस्तै बक्स', 'मुमेन्ट राई', 'विकासले  न्यु', 'तीर्थ नपाएको अहिले भन्दा', 'कलिलो बतासे गरिन्थ्यो', 'जनजाति', 'टाइटन कमिङ्ग थ्री  वा  रेट नेपाल  माइकल चाड एकान्त', 'छुटेका समष्टि कामहरू', 'माथि ठुलो होस्', 'दोस्रो नेपाल निर्भर भण्डारीको जुन मजा', 'धेरै लाग्ने बोल्नु पर्दैन', 'सही विधानलाई सकेको  अर्को कार्यक्रममा', 'होइन   ...
# Saving model checkpoint to ./test/checkpoint-2
# Configuration saved in ./test/checkpoint-2/config.json
# Model weights saved in ./test/checkpoint-2/pytorch_model.bin
# Configuration saved in ./test/checkpoint-2/preprocessor_config.json
# Deleting older checkpoint [test/checkpoint-24] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4563
#   Batch size = 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# /opt/conda/lib/python3.8/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1438                     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
#    1439
# -> 1440                     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1441                 else:
#    1442                     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# /opt/conda/lib/python3.8/site-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1563         metrics = None
#    1564         if self.control.should_evaluate:
# -> 1565             metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    1566             self._report_to_hp_search(trial, epoch, metrics)
#    1567
#
# /opt/conda/lib/python3.8/site-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    2202
#    2203         eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 2204         output = eval_loop(
#    2205             eval_dataloader,
#    2206             description="Evaluation",
#
# /opt/conda/lib/python3.8/site-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    2366         observed_num_examples = 0
#    2367         # Main evaluation loop
# -> 2368         for step, inputs in enumerate(dataloader):
#    2369             # Update the observed num examples
#    2370             observed_batch_size = find_batch_size(inputs)
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /opt/conda/lib/python3.8/site-packages/datasets/arrow_dataset.py in __getitem__(self, key)
#    1924     def __getitem__(self, key):  # noqa: F811
#    1925         """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 1926         return self._getitem(
#    1927             key,
#    1928         )
#
# /opt/conda/lib/python3.8/site-packages/datasets/arrow_dataset.py in _getitem(self, key, decoded, **kwargs)
#    1909         formatter = get_formatter(format_type, features=self.features, decoded=decoded, **format_kwargs)
#    1910         pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 1911         formatted_output = format_table(
#    1912             pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    1913         )
#
# /opt/conda/lib/python3.8/site-packages/datasets/formatting/formatting.py in format_table(table, key, formatter, format_columns, output_all_columns)
#     537     else:
#     538         pa_table_to_format = pa_table.drop(col for col in pa_table.column_names if col not in format_columns)
# --> 539         formatted_output = formatter(pa_table_to_format, query_type=query_type)
#     540         if output_all_columns:
#     541             if isinstance(formatted_output, MutableMapping):
#
# /opt/conda/lib/python3.8/site-packages/datasets/formatting/formatting.py in __call__(self, pa_table, query_type)
#     278     def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFormat, BatchFormat]:
#     279         if query_type == "row":
# --> 280             return self.format_row(pa_table)
#     281         elif query_type == "column":
#     282             return self.format_column(pa_table)
#
# /opt/conda/lib/python3.8/site-packages/datasets/formatting/formatting.py in format_row(self, pa_table)
#     307 class PythonFormatter(Formatter[dict, list, dict]):
#     308     def format_row(self, pa_table: pa.Table) -> dict:
# --> 309         row = self.python_arrow_extractor().extract_row(pa_table)
#     310         if self.decoded:
#     311             row = self.python_features_decoder.decode_row(row)
#
# /opt/conda/lib/python3.8/site-packages/datasets/formatting/formatting.py in extract_row(self, pa_table)
#     137 class PythonArrowExtractor(BaseArrowExtractor[dict, list, dict]):
#     138     def extract_row(self, pa_table: pa.Table) -> dict:
# --> 139         return _unnest(pa_table.to_pydict())
#     140
#     141     def extract_column(self, pa_table: pa.Table) -> list:
#
# KeyboardInterrupt:

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to wav2vec2-large-xlsr-300m-nepali
# Configuration saved in wav2vec2-large-xlsr-300m-nepali/config.json
# Model weights saved in wav2vec2-large-xlsr-300m-nepali/pytorch_model.bin
# Configuration saved in wav2vec2-large-xlsr-300m-nepali/preprocessor_config.json
# Dropping the following result as it does not have all the necessary fields:
# {}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 3.37k/1.18G [00:00<?, ?B/s]
# To https://huggingface.co/prajin/wav2vec2-large-xlsr-300m-nepali
#    2889e67..e7edbaf  main -> main

# %%
# trainer.save_metrics(all, metrics)
